# %% [markdown]
# # Road Accident Dataset - Exploratory Data Analysis
#
# India records one of the highest numbers of road accidents globally, leading to significant loss of life and property every year. Factors such as overspeeding, poor road conditions, weather, and traffic violations contribute heavily to these incidents. Analyzing accident data helps in identifying key risk factors and supports the development of preventive measures for safer roads.

# %% [markdown]
# # 1: Data Preparation & Cleaning

# %%
# Load required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
df = pd.read_csv("/content/accident_prediction_india.csv")
# kaggle/input/india-road-accident-dataset-predictive-analysis/accident_prediction_india.csv
df
# Out:
#              State Name City Name  Year      Month Day of Week Time of Day  \
# 0     Jammu and Kashmir   Unknown  2021        May      Monday       01:46
# 1         Uttar Pradesh   Lucknow  2018    January   Wednesday       21:30
# 2          Chhattisgarh   Unknown  2023        May   Wednesday       05:37
# 3         Uttar Pradesh   Lucknow  2020       June    Saturday       00:31
# 4                Sikkim   Unknown  2021     August    Thursday       11:21
# ...                 ...       ...   ...        ...         ...         ...
# 2995         Tamil Nadu   Chennai  2021    January      Sunday       01:15
# 2996        Uttarakhand   Unknown  2018       July      Sunday       10:12
# 2997          Meghalaya   Unknown  2021    January    Thursday       19:34
# 2998          Meghalaya   Unknown  2023       June      Sunday       20:54
# 2999  Arunachal Pradesh   Unknown  2020  September      Monday       07:19
#
#      Accident Severity  Number of Vehicles Involved Vehicle Type Involved  \
# 0              Serious                            5                 Cycle
# 1                Minor                            5                 Truck
# 2                Minor                            5            Pedestrian
# 3                Minor                            3                   Bus
# 4                Minor                            5                 Cycle
# ...                ...                          ...                   ...
# 2995             Minor                            5                 Truck
# 2996             Fatal                            3                   Car
# 2997             Minor                            2           Two-Wheeler
# 2998             Fatal                            1                 Cycle
# 2999             Fatal                            5                 Cycle
#
#       Number of Casualties  ...         Road Type      Road Condition  \
# 0                        0  ...  National Highway                 Wet
# 1                        5  ...        Urban Road                 Dry
# 2                        6  ...  National Highway  Under Construction
# 3                       10  ...     State Highway                 Dry
# 4                        7  ...        Urban Road                 Wet
# ...                    ...  ...               ...                 ...
# 2995                     4  ...  National Highway                 Wet
# 2996                     3  ...        Urban Road  Under Construction
# 2997                     8  ...  National Highway                 Dry
# 2998                     9  ...        Urban Road  Under Construction
# 2999                     1  ...  National Highway  Under Construction
#
#      Lighting Conditions Traffic Control Presence Speed Limit (km/h)  \
# 0                   Dark                    Signs                 61
# 1                   Dusk                    Signs                 92
# 2                   Dawn                    Signs                120
# 3                   Dark                  Signals                 76
# 4                   Dusk                    Signs                115
# ...                  ...                      ...                ...
# 2995                Dark                    Signs                 74
# 2996            Daylight                      NaN                 86
# 2997                Dark                    Signs                 47
# 2998            Daylight                    Signs                 60
# 2999            Daylight                      NaN                 40
#
#      Driver Age  Driver Gender  Driver License Status Alcohol Involvement  \
# 0            66           Male                    NaN                 Yes
# 1            60           Male                    NaN                 Yes
# 2            26         Female                    NaN                  No
# 3            34         Female                  Valid                 Yes
# 4            30           Male                    NaN                  No
# ...         ...            ...                    ...                 ...
# 2995         43           Male                Expired                 Yes
# 2996         23         Female                    NaN                 Yes
# 2997         57         Female                  Valid                 Yes
# 2998         28         Female                Expired                 Yes
# 2999         66           Male                    NaN                 Yes
#
#      Accident Location Details
# 0                        Curve
# 1                Straight Road
# 2                       Bridge
# 3                Straight Road
# 4                 Intersection
# ...                        ...
# 2995              Intersection
# 2996              Intersection
# 2997              Intersection
# 2998                    Bridge
# 2999                    Bridge
#
# [3000 rows x 22 columns]

# %% [markdown]
# ### Basic info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State Name                   3000 non-null   object
#  1   City Name                    3000 non-null   object
#  2   Year                         3000 non-null   int64
#  3   Month                        3000 non-null   object
#  4   Day of Week                  3000 non-null   object
#  5   Time of Day                  3000 non-null   object
#  6   Accident Severity            3000 non-null   object
#  7   Number of Vehicles Involved  3000 non-null   int64
#  8   Vehicle Type Involved        3000 non-null   object
#  9   Number of Casualties         3000 non-null   int64
#  10  Number of Fatalities         3000 non-null   int64
#  11  Weather Conditions           3000 non-null   object
#  12  Road Type                    3000 non-null   object
#  13  Road Condition               3000 non-null   object
#  14  Lighting Conditions          3000 non-null   object
#  15  Traffic Control Presence     2284 non-null   object
#  16  Speed Limit (km/h)           3000 non-null   int64
#  17  Driver Age                   3000 non-null   int64
#  18  Driver Gender                3000 non-null   object
#  19  Driver License Status        2025 non-null   object
#  20  Alcohol Involvement          3000 non-null   object
#  21  Accident Location Details    3000 non-null   object
# dtypes: int64(6), object(16)
# memory usage: 515.8+ KB

# %% [markdown]
# The dataset consists of 3000 rows and 22 columns with both numerical and categorical features. While most fields are complete, some columns such as Traffic Control Presence and Driver License Status contain missing values that need to be handled before analysis.

# %%
df.head()
# Out:
#           State Name City Name  Year    Month Day of Week Time of Day  \
# 0  Jammu and Kashmir   Unknown  2021      May      Monday       01:46
# 1      Uttar Pradesh   Lucknow  2018  January   Wednesday       21:30
# 2       Chhattisgarh   Unknown  2023      May   Wednesday       05:37
# 3      Uttar Pradesh   Lucknow  2020     June    Saturday       00:31
# 4             Sikkim   Unknown  2021   August    Thursday       11:21
#
#   Accident Severity  Number of Vehicles Involved Vehicle Type Involved  \
# 0           Serious                            5                 Cycle
# 1             Minor                            5                 Truck
# 2             Minor                            5            Pedestrian
# 3             Minor                            3                   Bus
# 4             Minor                            5                 Cycle
#
#    Number of Casualties  ...         Road Type      Road Condition  \
# 0                     0  ...  National Highway                 Wet
# 1                     5  ...        Urban Road                 Dry
# 2                     6  ...  National Highway  Under Construction
# 3                    10  ...     State Highway                 Dry
# 4                     7  ...        Urban Road                 Wet
#
#   Lighting Conditions Traffic Control Presence Speed Limit (km/h) Driver Age  \
# 0                Dark                    Signs                 61         66
# 1                Dusk                    Signs                 92         60
# 2                Dawn                    Signs                120         26
# 3                Dark                  Signals                 76         34
# 4                Dusk                    Signs                115         30
#
#    Driver Gender  Driver License Status Alcohol Involvement  \
# 0           Male                    NaN                 Yes
# 1           Male                    NaN                 Yes
# 2         Female                    NaN                  No
# 3         Female                  Valid                 Yes
# 4           Male                    NaN                  No
#
#   Accident Location Details
# 0                     Curve
# 1             Straight Road
# 2                    Bridge
# 3             Straight Road
# 4              Intersection
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (3000, 22)

# %%
# Missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# State Name                       0
# City Name                        0
# Year                             0
# Month                            0
# Day of Week                      0
# Time of Day                      0
# Accident Severity                0
# Number of Vehicles Involved      0
# Vehicle Type Involved            0
# Number of Casualties             0
# Number of Fatalities             0
# Weather Conditions               0
# Road Type                        0
# Road Condition                   0
# Lighting Conditions              0
# Traffic Control Presence       716
# Speed Limit (km/h)               0
# Driver Age                       0
# Driver Gender                    0
# Driver License Status          975
# Alcohol Involvement              0
# Accident Location Details        0
# dtype: int64

# %% [markdown]
# The dataset is mostly clean with no missing values in most columns, except for Traffic Control Presence (716) and Driver License Status (975) which may need imputation or removal.

# %%
# Convert Time of Day to datetime
df['Time of Day'] = pd.to_datetime(df['Time of Day'], format="%H:%M", errors="coerce").dt.time
df['Time of Day']
# Out:
# 0       01:46:00
# 1       21:30:00
# 2       05:37:00
# 3       00:31:00
# 4       11:21:00
#           ...
# 2995    01:15:00
# 2996    10:12:00
# 2997    19:34:00
# 2998    20:54:00
# 2999    07:19:00
# Name: Time of Day, Length: 3000, dtype: object

# %% [markdown]
# Convert the "Time of Day" column from string format (HH:MM) to proper datetime.time objects. Any invalid or unparsable values will be set to NaT (Not a Time) due to errors="coerce".

# %%
# Create Date column
df['Date'] = pd.to_datetime(df['Year'].astype(str) + "-" + df['Month'] + "-01", errors="coerce")
df['Date']
# Out:
# 0      2021-05-01
# 1      2018-01-01
# 2      2023-05-01
# 3      2020-06-01
# 4      2021-08-01
#           ...
# 2995   2021-01-01
# 2996   2018-07-01
# 2997   2021-01-01
# 2998   2023-06-01
# 2999   2020-09-01
# Name: Date, Length: 3000, dtype: datetime64[ns]

# %% [markdown]
# Create a new 'Date' column by combining 'Year' and 'Month'
# Convert them into a proper datetime format (YYYY-MM-01)
# 'errors="coerce"' ensures invalid dates are set to NaT instead of raising errors.

# %% [markdown]
# ### Clean invalid data

# %%
df = df[df['Driver Age'] > 15]
df.head()
# Out:
#           State Name City Name  Year    Month Day of Week Time of Day  \
# 0  Jammu and Kashmir   Unknown  2021      May      Monday    01:46:00
# 1      Uttar Pradesh   Lucknow  2018  January   Wednesday    21:30:00
# 2       Chhattisgarh   Unknown  2023      May   Wednesday    05:37:00
# 3      Uttar Pradesh   Lucknow  2020     June    Saturday    00:31:00
# 4             Sikkim   Unknown  2021   August    Thursday    11:21:00
#
#   Accident Severity  Number of Vehicles Involved Vehicle Type Involved  \
# 0           Serious                            5                 Cycle
# 1             Minor                            5                 Truck
# 2             Minor                            5            Pedestrian
# 3             Minor                            3                   Bus
# 4             Minor                            5                 Cycle
#
#    Number of Casualties  ...      Road Condition Lighting Conditions  \
# 0                     0  ...                 Wet                Dark
# 1                     5  ...                 Dry                Dusk
# 2                     6  ...  Under Construction                Dawn
# 3                    10  ...                 Dry                Dark
# 4                     7  ...                 Wet                Dusk
#
#   Traffic Control Presence Speed Limit (km/h) Driver Age Driver Gender  \
# 0                    Signs                 61         66          Male
# 1                    Signs                 92         60          Male
# 2                    Signs                120         26        Female
# 3                  Signals                 76         34        Female
# 4                    Signs                115         30          Male
#
#    Driver License Status  Alcohol Involvement Accident Location Details  \
# 0                    NaN                  Yes                     Curve
# 1                    NaN                  Yes             Straight Road
# 2                    NaN                   No                    Bridge
# 3                  Valid                  Yes             Straight Road
# 4                    NaN                   No              Intersection
#
#         Date
# 0 2021-05-01
# 1 2018-01-01
# 2 2023-05-01
# 3 2020-06-01
# 4 2021-08-01
#
# [5 rows x 23 columns]

# %% [markdown]
# Only rows with Driver Age > 15 were kept, since drivers below 16 are not legally valid. Others were removed as invalid data.

# %%
df = df[df['Speed Limit (km/h)'] < 201]
df.head()
# Out:
#           State Name City Name  Year    Month Day of Week Time of Day  \
# 0  Jammu and Kashmir       NaN  2021      May      Monday    01:46:00
# 1      Uttar Pradesh   Lucknow  2018  January   Wednesday    21:30:00
# 2       Chhattisgarh       NaN  2023      May   Wednesday    05:37:00
# 3      Uttar Pradesh   Lucknow  2020     June    Saturday    00:31:00
# 4             Sikkim       NaN  2021   August    Thursday    11:21:00
#
#   Accident Severity  Number of Vehicles Involved Vehicle Type Involved  \
# 0           Serious                            5                 Cycle
# 1             Minor                            5                 Truck
# 2             Minor                            5            Pedestrian
# 3             Minor                            3                   Bus
# 4             Minor                            5                 Cycle
#
#    Number of Casualties  ...      Road Condition Lighting Conditions  \
# 0                     0  ...                 Wet                Dark
# 1                     5  ...                 Dry                Dusk
# 2                     6  ...  Under Construction                Dawn
# 3                    10  ...                 Dry                Dark
# 4                     7  ...                 Wet                Dusk
#
#   Traffic Control Presence Speed Limit (km/h) Driver Age Driver Gender  \
# 0                    Signs                 61         66          Male
# 1                    Signs                 92         60          Male
# 2                    Signs                120         26        Female
# 3                  Signals                 76         34        Female
# 4                    Signs                115         30          Male
#
#    Driver License Status  Alcohol Involvement Accident Location Details  \
# 0                    NaN                  Yes                     Curve
# 1                    NaN                  Yes             Straight Road
# 2                    NaN                   No                    Bridge
# 3                  Valid                  Yes             Straight Road
# 4                    NaN                   No              Intersection
#
#         Date
# 0 2021-05-01
# 1 2018-01-01
# 2 2023-05-01
# 3 2020-06-01
# 4 2021-08-01
#
# [5 rows x 23 columns]

# %% [markdown]
# *Speed limit > 200 km/h kante ekkuva unna viluvalanu tholaginchadamainadi, endukante vasthava prapanchamlo atuvanti parimithulu undavu mariyu aa data thappu.*

# %%
df.replace("Unknown", np.nan, inplace=True)
df.head()
# Out:
#           State Name City Name  Year    Month Day of Week Time of Day  \
# 0  Jammu and Kashmir       NaN  2021      May      Monday    01:46:00
# 1      Uttar Pradesh   Lucknow  2018  January   Wednesday    21:30:00
# 2       Chhattisgarh       NaN  2023      May   Wednesday    05:37:00
# 3      Uttar Pradesh   Lucknow  2020     June    Saturday    00:31:00
# 4             Sikkim       NaN  2021   August    Thursday    11:21:00
#
#   Accident Severity  Number of Vehicles Involved Vehicle Type Involved  \
# 0           Serious                            5                 Cycle
# 1             Minor                            5                 Truck
# 2             Minor                            5            Pedestrian
# 3             Minor                            3                   Bus
# 4             Minor                            5                 Cycle
#
#    Number of Casualties  ...      Road Condition Lighting Conditions  \
# 0                     0  ...                 Wet                Dark
# 1                     5  ...                 Dry                Dusk
# 2                     6  ...  Under Construction                Dawn
# 3                    10  ...                 Dry                Dark
# 4                     7  ...                 Wet                Dusk
#
#   Traffic Control Presence Speed Limit (km/h) Driver Age Driver Gender  \
# 0                    Signs                 61         66          Male
# 1                    Signs                 92         60          Male
# 2                    Signs                120         26        Female
# 3                  Signals                 76         34        Female
# 4                    Signs                115         30          Male
#
#    Driver License Status  Alcohol Involvement Accident Location Details  \
# 0                    NaN                  Yes                     Curve
# 1                    NaN                  Yes             Straight Road
# 2                    NaN                   No                    Bridge
# 3                  Valid                  Yes             Straight Road
# 4                    NaN                   No              Intersection
#
#         Date
# 0 2021-05-01
# 1 2018-01-01
# 2 2023-05-01
# 3 2020-06-01
# 4 2021-08-01
#
# [5 rows x 23 columns]

# %% [markdown]
# "Unknown" values have been replaced with NaN and treated as missing data, making data cleaning and analysis easier.

# %%
print("Data after cleaning:", df.shape)
# Out:
# Data after cleaning: (3000, 23)

# %% [markdown]
# # 2: Exploratory Analysis & Visualization

# %%
# Descriptive Statistics:
df.describe()
# Out:
#               Year  Number of Vehicles Involved  Number of Casualties  \
# count  3000.000000                  3000.000000           3000.000000
# mean   2020.530000                     2.996000              5.066000
# min    2018.000000                     1.000000              0.000000
# 25%    2019.000000                     2.000000              2.000000
# 50%    2021.000000                     3.000000              5.000000
# 75%    2022.000000                     4.000000              8.000000
# max    2023.000000                     5.000000             10.000000
# std       1.683858                     1.428285              3.214097
#
#        Number of Fatalities  Speed Limit (km/h)  Driver Age  \
# count           3000.000000         3000.000000  3000.00000
# mean               2.455333           74.940667    44.17700
# min                0.000000           30.000000    18.00000
# 25%                1.000000           51.000000    31.00000
# 50%                2.000000           75.000000    45.00000
# 75%                4.000000           99.000000    57.00000
# max                5.000000          120.000000    70.00000
# std                1.717650           26.765088    15.40286
#
#                                 Date
# count                           3000
# mean   2020-12-27 02:02:52.799999744
# min              2018-01-01 00:00:00
# 25%              2019-08-01 00:00:00
# 50%              2021-01-01 00:00:00
# 75%              2022-06-01 00:00:00
# max              2023-12-01 00:00:00
# std                              NaN

# %% [markdown]
# Provides summary statistics of numerical columns such as count, mean, standard deviation, minimum, maximum, and quartile values (25%, 50%, 75%).
# Helps in understanding data distribution and detecting outliers.

# %%
# Histogram
df['Driver Age'].plot(kind='hist', bins=20, title="Driver Age Distribution")
plt.show()

# %% [markdown]
# Plotting a histogram to visualize the distribution of driver ages 'bins=20' divides the age range into 20 intervals
# Helps to identify common age groups, spread, and skewness in the data

# %%
df['Speed Limit (km/h)'].plot(kind='hist', bins=20, title="Speed Limit Distribution")
plt.show()

# %% [markdown]
# Plot a histogram to examine the distribution of driver ages
# 'bins=20' splits the age range into 20 equal intervals
# Useful for detecting common age groups, data spread, and skewness in age distribution

# %%
# Bar chart: Severity
df['Accident Severity'].value_counts().plot(kind='bar', title="Accident Severity Distribution")
plt.show()

# %% [markdown]
# Plot a bar chart to visualize the distribution of accident severity levels.
# This helps to understand how many accidents fall under each severity category
# (e.g., Fatal, Serious, Slight), giving insights into the overall severity trend in the dataset.

# %%
# Scatter: Speed vs Fatalities
plt.scatter(df['Speed Limit (km/h)'], df['Number of Fatalities'])
plt.xlabel("Speed Limit (km/h)")
plt.ylabel("Fatalities")
plt.title("Speed vs Fatalities")
plt.show()

# %% [markdown]
# Scatter plot to visualize the relationship between speed limit and number of fatalities.
# Each point represents a record from the dataset, where:
# X-axis → Speed Limit (km/h)
# Y-axis → Number of Fatalities
# The plot helps identify if higher speed limits are associated with more fatalities.

# %%
# Weather vs Accidents
df['Weather Conditions'].value_counts().plot(kind='bar', title="Accidents by Weather Conditions")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# This visualization shows the distribution of accidents under different weather conditions. By plotting the frequency of accidents for each weather category, we can identify which weather conditions are most associated with higher accident occurrences. This helps in understanding environmental risk factors for road safety.

# %% [markdown]
# # 3: Ask & Answer Questions

# %%
# Q1: Which state has most accidents?
state_accidents = df['State Name'].value_counts()
print("Q1: State with most accidents:\n", state_accidents.head())
# Out:
# Q1: State with most accidents:
#  State Name
# Goa                  109
# Sikkim               108
# Delhi                108
# Uttarakhand          106
# Jammu and Kashmir    105
# Name: count, dtype: int64

# %% [markdown]
# Goa recorded the highest number of accidents (109), followed closely by Sikkim (108) and Delhi (108). The difference between the top states is minimal, indicating that multiple states face similar accident frequencies.

# %%
# Q2: Which vehicle type is most fatal?
fatal_vehicle = df[df['Accident Severity']=="Fatal"]['Vehicle Type Involved'].value_counts()
print("Q2: Vehicle type in fatal accidents:\n", fatal_vehicle)
# Out:
# Q2: Vehicle type in fatal accidents:
#  Vehicle Type Involved
# Bus              167
# Cycle            167
# Pedestrian       134
# Truck            132
# Two-Wheeler      131
# Auto-Rickshaw    129
# Car              125
# Name: count, dtype: int64

# %% [markdown]
# Fatal accidents are most frequently associated with buses and cycles, followed by pedestrians and trucks, indicating higher vulnerability for both non-motorized and heavy vehicles.

# %%
# Q3: Severity vs Weather
severity_weather = pd.crosstab(df['Weather Conditions'], df['Accident Severity'])
print("Q3: Severity vs Weather:\n", severity_weather)
severity_weather.plot(kind="bar", stacked=True, figsize=(10,5))
plt.title("Accident Severity vs Weather")
plt.show()
# Out:
# Q3: Severity vs Weather:
#  Accident Severity   Fatal  Minor  Serious
# Weather Conditions
# Clear                 190    202      182
# Foggy                 195    174      207
# Hazy                  200    203      205
# Rainy                 197    224      210
# Stormy                203    231      177

# %% [markdown]
# Clear weather also sees many accidents, but severe cases increase notably in foggy and rainy conditions, suggesting reduced visibility and slippery roads play a major role.

# %% [markdown]
# Accidents are fairly consistent throughout the day, with slight peaks in the early morning (around 3–8 AM) and evening (after 5 PM), indicating higher risk during commuting hours.

# %% [markdown]
# # Step 4: Summary & Conclusion

# %% [markdown]
# --- Summary & Insights ---
# 1. Most accidents occurred in: Goa
# 2. Fatal accidents are mostly linked with: Bus
# 3. Foggy/Stormy conditions show higher severity.
# 4. Late night & early morning hours show more severe accidents.
#
# Conclusion: Safety measures should focus on high-risk states, poor weather, and nighttime driving.
